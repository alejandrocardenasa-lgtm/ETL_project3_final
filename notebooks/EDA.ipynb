# %%
import pandas as pd

df = pd.read_csv("../data/raw/meteostat_daily_globalv2.csv")

df = pd.read_csv("../data/raw/temperature_observations_colombia_transformed.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62070 entries, 0 to 62069
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    62070 non-null  str
#  1   tavg    61258 non-null  float64
#  2   tmin    58864 non-null  float64
#  3   tmax    58941 non-null  float64
#  4   prcp    48207 non-null  float64
#  5   snow    12368 non-null  float64
#  6   wdir    0 non-null      float64
#  7   wspd    55747 non-null  float64
#  8   wpgt    7196 non-null   float64
#  9   pres    40761 non-null  float64
#  10  tsun    6807 non-null   float64
#  11  city    62070 non-null  str
# dtypes: float64(10), str(2)
# memory usage: 5.7 MB
# None

# %%
print(df.isnull().sum())
# Out:
# date        0
# tavg      812
# tmin     3206
# tmax     3129
# prcp    13863
# snow    49702
# wdir    62070
# wspd     6323
# wpgt    54874
# pres    21309
# tsun    55263
# city        0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.describe())
# Out:
#                tavg          tmin          tmax          prcp          snow  \
# count  61258.000000  58864.000000  58941.000000  48207.000000  12368.000000
# mean      15.132409     10.735234     19.888648      2.245767      2.867481
# std        7.095107      7.025826      8.104621      8.082023     18.773864
# min      -17.800000    -19.600000    -12.600000      0.000000      0.000000
# 25%       10.100000      5.600000     14.000000      0.000000      0.000000
# 50%       15.900000     10.900000     20.700000      0.000000      0.000000
# 75%       20.100000     16.000000     26.000000      0.800000      0.000000
# max       34.400000     30.500000     41.700000    261.100000    360.000000
#
#        wdir          wspd         wpgt          pres         tsun
# count   0.0  55747.000000  7196.000000  40761.000000  6807.000000
# mean    NaN     12.362317    36.959950   1015.968595   262.572058
# std     NaN      5.250392    12.831722      8.054647   267.913778
# ...

# %%
print(df["city"].unique())
# Out:
# <StringArray>
# [       'Berlin',          'Lima',   'Mexico_City',  'Buenos_Aires',
#       'Santiago',        'Madrid',         'Paris',        'London',
#          'Tokyo', 'Washington_DC']
# Length: 10, dtype: str

# %%
df["city"].value_counts()
# Out:
# city
# Berlin           6207
# Lima             6207
# Mexico_City      6207
# Buenos_Aires     6207
# Santiago         6207
# Madrid           6207
# Paris            6207
# London           6207
# Tokyo            6207
# Washington_DC    6207
# Name: count, dtype: int64

# %%
# validacion de granularidad - 1 ciudad + 1 dia + variables climaticas
df.groupby(["city", "date"]).size().value_counts()
# Out:
# 1    62070
# Name: count, dtype: int64

# %%
# cobertura de fechas
print(df["date"].min(), df["date"].max())
# Out:
# 2003-01-01 00:00:00 2019-12-31 00:00:00
